# %% [markdown]
# ## General Strategy for Evaluating Model Performance

# %% [markdown]
#     1. Extract Features using multiple Feature Extraction Models
#     2. Store extracted features
#     3. Evaluate using consistent Evaluation Script
