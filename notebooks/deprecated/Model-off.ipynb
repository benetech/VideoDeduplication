# %% [markdown]
# ## Model Results Comparison
#
# Objectives:
#
#     1. Establish clear concepts / methodology for assessment
#     2. Assess Vendor Performance using definitions above
#     3. Assess Model performance by using same metrics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import os

# %%
# Test Dataset information
videos = glob('/datadrive/test_dataset/**')
VIDEOS_LIST = os.path.abspath('syria_videos.txt')
FRAME_LEVEL_SAVE_FOLDER = os.path.abspath('/datadrive/intermediate/frame_level')
VIDEO_LEVEL_SAVE_FOLDER = '/datadrive/intermediate/video_level'
VIDEO_SIGNATURES_SAVE_FOLDER = '/datadrive/intermediate/video_signatures'

# %%
len(videos)
# Out:
# 3843

# %%
vendorquery_df = pd.read_excel('Benetech_Deduping Report_25Jan2019.xlsx',sheet_name='Queries')

# %%
vendorquery_df['filename'] = vendorquery_df['Q ID'].apply(lambda x:x.split('/')[-1])
vendorquery_df.head()
# Out:
#                                                 Q ID  \
# 0  s3.videocitestest/_5g95MUIieM-7673d38ccc6e268b...
# 1  s3.videocitestest/_a8srUndP8Y-48644a14cbb89129...
# 2  s3.videocitestest/_afTSrDroHs-06d2f1b68aabc513...
# 3  s3.videocitestest/_bja8VCDY_w-129f9c4b34cfe622...
# 4  s3.videocitestest/_cmXD8JT2hY-2b0c77a29384fe93...
#
#                                            filename
# 0  _5g95MUIieM-7673d38ccc6e268bf6d79e61f388d37b.mp4
# 1  _a8srUndP8Y-48644a14cbb89129dccdcde0f5715de3.mp4
# 2  _afTSrDroHs-06d2f1b68aabc513424f74184663caa9.mp4
# 3  _bja8VCDY_w-129f9c4b34cfe6227d4311231e08ee3f.mp4
# 4  _cmXD8JT2hY-2b0c77a29384fe9387b37408888ea96e.mp4

# %%
vendorquery_df['filename'].value_counts()
# Out:
# 358ef46f0c2d4125945bf0d547e7ff0a.mp4                 1
# 0dbdb8c12bfa4e75880b606f3bb4a43b.webm                1
# B68yHSlYjgo-15999884aee1a49a926462368fc798aa.mp4     1
# 5865784a2a654f36a98bf8a808a16a63.webm                1
# 74f788b680e24a789e5820e7e5e4b26f.ogv                 1
# 13146ea8523a4b24b111df7727bc9380.webm                1
# b3a4d1f77cda451dabd8d4be294c4958.mp4                 1
# X1zpH3AH-Q0-fc0726cb43f191159c53ac96ecd56b8b.mp4     1
# RU7-9l71zWs-e2a2099fd673e8874930816fb8fe387f.mp4     1
# a3aa0f40d50645b0b7fda69ea05bf172.mp4                 1
# 6975a5a021794433ac22918eff8458cc.ogv                 1
# 6bb05f5ac21b44de9566c1bec4e9230e.mp4                 1
# 69865809e5d34b4dab7d8cb9937b68de.webm                1
# 9720ef42cece4d818db2f12c01a11718.mp4                 1
# d2c49de30ec5495fbc8bd60163f1360c.webm                1
# 06708214fe254a72aacb2ee15cea4546.mp4                 1
# 49fbb4a3fc254702974717b464b80173.ogv                 1
# d26468ddc9eb4436906535812429566b.mp4                 1
# 65bdfeb5b0524cecbf9295341f0dc922.webm                1
# 26f70b466b4849baae6cc6ba1d32dcea.ogv                 1
# bb181f65860e44968ceeb5852adce575.webm                1
# WuKTBwvLoK8-34f45afc3ff9f347c45627b19c6ea459.mp4     1
# _kDvOThYp1g-b71a7ce85885f3c76e5915b1df512be9.mp4     1
# v7z0VsWd8pI-c944ccefbfd3159ac5bc520c88f9ad4b.mp4     1
# bzCshxZK0Ks-43956b388393bf834ef30e301b42b62c.webm    1
# 338fc9531cf24c9c98903352e73023c3.webm                1
# 0c7f246160174eb4ab7a0e26199d4014.mp4                 1
# a1930b845b1d4a9a8834e7df0e2500f6.mp4                 1
# 8213c29dd3aa4970a6134adc68b66e28.mp4                 1
# XjlMGC3wJIQ-003358afc7970a7bc59e4b28bc5d8857.mp4     1
#                                                     ..
# 7g_SwED3hbw-2dcd18076b9880fedba96fc4303c5d70.mp4     1
# b13d55c5af4f4123a34d3e90f3d528e2.ogv                 1
# 802a9c6867b042b48e148bf2e48a4979.webm                1
# shS7IYROeME-7fbb8450de64a939b0fcc986e5866430.mp4     1
# 5IqvQ6TBnk0-ebcc4ea1c9c8fd4d8f73b12ad82ae118.mp4     1
# c315f76f1cda47ffa3f463a806c957ee.ogv                 1
# ohngCDAw4QI-50c283e39de3da07592e9ccd3a3e4fa1.mp4     1
# 11529b58acf144d79cad1be343950a28.webm                1
# XHV60Kr9n7E-1c439b01e88338034c68745ca6235a47.mp4     1
# 142f2d5014524e58aa7554f95e9a4f87.webm                1
# d3394bffc6d249f9acceec330176c5fd.webm                1
# 448889657bfb47d8888225826059f15c.webm                1
# 2b94570a2be04349a9e1cd68af8ae621.webm                1
# Vf5S7BPZFxw-2bec231148b990b0e80a888e61f6f8c2.mp4     1
# 117c77d246ae481d93525d2a62e7ed64.mp4                 1
# 9MonVwvFCoA-c0c3c4d070fe071115ff17f6475e2692.mp4     1
# 6007218106064ad7b5eed1d910b55f4c.ogv                 1
# QYGBpEsN9uM-403092beb0dba66a514eadd9f8ed4b07.mp4     1
# u3VDtLG8E_Y-851998683165ea933867e69048bcd6b6.mp4     1
# iLB7KdVhOKA-33a2a2df13c6537d43304d7fd7b97b60.mp4     1
# 3e5187042ab745f4b058beddbb24efe5.ogv                 1
# a8d0efb460894939a5431a1f023f8b5c.webm                1
# 1a2215c577a044b2bb192b6b83e1eb42.webm                1
# 76tEEtW1n6c-d7945a1702f6614b4c141e87285bd565.mp4     1
# bc5518423b424509b56675dc139a8b11.webm                1
# 96af454a9f5f4192bf1c627e1efde95d.webm                1
# 314c164c34034403a71886b806d60591.mp4                 1
# L7G36hyDk2E-dadef06410431a513442df278acbf918.mp4     1
# 08f4a86a57074b27bba7c032481e74b2.mp4                 1
# 57d3b444ab0c4b138d8db16236906ffe.webm                1
# Name: filename, Length: 2500, dtype: int64

# %% [markdown]
# ## Match Query summary

# %%
# Vendor Results spreadsheet
vendor_df = pd.read_excel('Benetech_Deduping Report_25Jan2019.xlsx')
# Additional filename fields for both Query / Match Videos
vendor_df['q_filename'] = vendor_df['Q ID'].apply(lambda x:x.split('/')[-1])
vendor_df['m_filename'] = vendor_df['M ID'].apply(lambda x:x.split('/')[-1])
# 
unique_qs = vendor_df['q_filename'].value_counts().index
vendor_df.loc[vendor_df['q_filename'] == unique_qs[0],:]
# Out:
#                                                   Q ID  \
# 1    s3.videocitestest/QGFBGnpXMqE-07d9e6754f49d3eb...
# 71   s3.videocitestest/QGFBGnpXMqE-07d9e6754f49d3eb...
# 77   s3.videocitestest/QGFBGnpXMqE-07d9e6754f49d3eb...
# 163  s3.videocitestest/QGFBGnpXMqE-07d9e6754f49d3eb...
# 169  s3.videocitestest/QGFBGnpXMqE-07d9e6754f49d3eb...
# 175  s3.videocitestest/QGFBGnpXMqE-07d9e6754f49d3eb...
#
#                                                  Q URL  Q Duration  Q Width  \
# 1    https://videocitestest.s3.amazonaws.com/QGFBGn...          81      640
# 71   https://videocitestest.s3.amazonaws.com/QGFBGn...          81      640
# 77   https://videocitestest.s3.amazonaws.com/QGFBGn...          81      640
# 163  https://videocitestest.s3.amazonaws.com/QGFBGn...          81      640
# 169  https://videocitestest.s3.amazonaws.com/QGFBGn...          81      640
# 175  https://videocitestest.s3.amazonaws.com/QGFBGn...          81      640
#
#      Q Height  Q FPS                                               M ID  \
# 1         360   30.0  s3.videocitestest/6YmKwon4X0c-f518e04bd71707dd...
# 71        360   30.0  s3.videocitestest/sW02MYKmUaM-f8c6ef6974e0d853...
# 77        360   30.0  s3.videocitestest/018MsV21q00-3419176ec77eea4d...
# 163       360   30.0  s3.videocitestest/4fbf84566d434628bc6954a36e77...
# 169       360   30.0  s3.videocitestest/7faf034173f4451398b05e6f1686...
# 175       360   30.0  s3.videocitestest/4214d032b0924870a216958e84a7...
#
#                                                  M URL  M Duration M Status  \
# 1    https://videocitestest.s3.amazonaws.com/6YmKwo...         179    match
# 71   https://videocitestest.s3.amazonaws.com/sW02MY...          64    match
# 77   https://videocitestest.s3.amazonaws.com/018MsV...          81    match
# 163  https://videocitestest.s3.amazonaws.com/4fbf84...          79    match
# 169  https://videocitestest.s3.amazonaws.com/7faf03...          83    match
# 175  https://videocitestest.s3.amazonaws.com/4214d0...          86    match
#
#                                            q_filename  \
# 1    QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4
# 71   QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4
# 77   QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4
# 163  QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4
# 169  QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4
# 175  QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4
#
#                                            m_filename
# 1    6YmKwon4X0c-f518e04bd71707ddd985f89f03cc7784.mp4
# 71   sW02MYKmUaM-f8c6ef6974e0d853df113f45e1242628.mp4
# 77   018MsV21q00-3419176ec77eea4da5161cf6faa05a3d.mp4
# 163             4fbf84566d434628bc6954a36e7722d5.webm
# 169             7faf034173f4451398b05e6f1686a896.webm
# 175              4214d032b0924870a216958e84a7544a.ogv

# %%
vendor_df.shape
# Out:
# (303, 14)

# %%
vendor_df['q_filename'].value_counts()[:20]
# Out:
# QGFBGnpXMqE-07d9e6754f49d3eb87d95767bff7e696.mp4     6
# 550c6ee08ac64e31849862c60b810cb9.ogv                 5
# 4pcIA0Vx_Ok-a6ff21a834134a75701b950030cca07c.mp4     4
# a11fa902d2df4e7fb623d8f15dbbc907.webm                4
# 4ac1ad9c38934eaab7fa0146141c9354.mp4                 4
# 9b223626726c4e8db8d9fe683cb64c20.webm                4
# 743d8aef543e49f0901853f8ec239978.webm                3
# jU1MgcbSpwA-6a91a8bcbb42936aa2585d0f893fe0a3.mp4     3
# 20ef78f27905452db356123f68a38382.ogv                 3
# 04da0835050b472689abff6fbb47515c.ogv                 3
# 8885400fcf264e67babb46fbe1b8d290.mp4                 3
# ba2dac8a2a4b44659c53671358b6980a.ogv                 3
# GyaFEZujpbY-e2e5d448e968fd988bf891592ef744af.mp4     3
# d037ae1a2c8a43938139252e660dec04.webm                3
# 7157713dfa9e45ea8e5a02d7eedc9bc8.mp4                 2
# 7472a034c4954c289f9e3064b0bbbbce.ogv                 2
# 412af188b7c64b43a51b870134a53b7b.webm                2
# GhmiBQWoT0Y-9ba30d949fae62dfc38da4dffe6563a3.webm    2
# c5bcecc23edb4ca6af691ab014b73370.webm                2
# 48ab694a26e647cd96e831ca9fe390ad.mp4                 2
# Name: q_filename, dtype: int64

# %% [markdown]
# Assumption: Each query on the Queries sheet, was performed against the remaining dataset. This explains the reason why there are multiple queries for a given filename.

# %%
augmentation_manifesto = pd.read_csv('/home/felipeb/augmenter/augmented_dataset_manifest')

# %%
augmentation_manifesto['original_basename'] = augmentation_manifesto['file_path'].apply(lambda x:os.path.basename(x))
test_dataset = [os.path.basename(x) for x in videos]
used = augmentation_manifesto.loc[augmentation_manifesto['new_filename'].isin(test_dataset),:]
used['isAugmented'] = True
# Out:
# /home/felipeb/.conda/envs/winnow/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
augmented_files = used['new_filename'].values

# %%
vendor_df['augmented_q'] = False
vendor_df['augmented_m'] = False

vendor_df.loc[vendor_df['q_filename'].isin(augmented_files),'augmented_q'] = True
vendor_df.loc[vendor_df['m_filename'].isin(augmented_files),'augmented_m'] = True

# %% [markdown]
# In order to assess performance, we'll we'll restrain the problem to the files that we actually have the answer (augmented files). Even though there might be additional files for which the vendor has reported the right answer but the only way to verify it is to perform manual validation.

# %%
vendorquery_df.head()
# Out:
#                                                 Q ID  \
# 0  s3.videocitestest/_5g95MUIieM-7673d38ccc6e268b...
# 1  s3.videocitestest/_a8srUndP8Y-48644a14cbb89129...
# 2  s3.videocitestest/_afTSrDroHs-06d2f1b68aabc513...
# 3  s3.videocitestest/_bja8VCDY_w-129f9c4b34cfe622...
# 4  s3.videocitestest/_cmXD8JT2hY-2b0c77a29384fe93...
#
#                                            filename
# 0  _5g95MUIieM-7673d38ccc6e268bf6d79e61f388d37b.mp4
# 1  _a8srUndP8Y-48644a14cbb89129dccdcde0f5715de3.mp4
# 2  _afTSrDroHs-06d2f1b68aabc513424f74184663caa9.mp4
# 3  _bja8VCDY_w-129f9c4b34cfe6227d4311231e08ee3f.mp4
# 4  _cmXD8JT2hY-2b0c77a29384fe9387b37408888ea96e.mp4

# %%
m_q = dict(zip(vendor_df['m_filename'],vendor_df['q_filename']))

# %%
def matching(x,d):
    try:
        return d[x]
    except:
        return x

# %%
vendorquery_df['match_filename'] = vendorquery_df['filename'].apply(lambda x:matching(x,m_q))

# %%
vendorquery_df['match_filename'].nunique()
# Out:
# 2356

# %%
vendorquery_df['isUnique'] = vendorquery_df.apply(lambda x: x['filename'] == x['match_filename'],axis=1)

# %%
vendorquery_df.isUnique.value_counts()
# Out:
# True     2246
# False     254
# Name: isUnique, dtype: int64

# %% [markdown]
# Unless there are two files from the same source, or the source itself, we cannot make any assumptions about a file being unique. Now we need to implement a few helper functions to evaluate the results in a way to account for these details.

# %%
augmentation_manifesto.head()
# Out:
#    Unnamed: 0 banner bitrate  color_intensity         crop extension  \
# 0           0    NaN     32k             0.42          NaN       NaN
# 1           1    NaN     64k             0.24          NaN       NaN
# 2           2  False     NaN              NaN          NaN       NaN
# 3           3    NaN     NaN              NaN  [0.11 0.15]       NaN
# 4           4    NaN     NaN              NaN  [0.04 0.03]       NaN
#
#                                            file_path  intensity  \
# 0  /datadrive/videos/BVx0nR366sk-3b0933b1902d9a66...      -0.09
# 1  /datadrive/videos/6Y1uTg7wCV8-b068dba553b7529e...      -0.05
# 2  /datadrive/videos/VuW-M9TB7tM-73472a9187f950d4...      -0.12
# 3  /datadrive/videos/gMz2bJykKaY-31b60bdf2a061902...        NaN
# 4  /datadrive/videos/6QWIAsPOlxM-907ba6ac2932e487...      -0.19
#
#                 logo  offset  shaky  shaky_after_logo  speed_change  \
# 0                NaN     NaN  False              True         -0.09
# 1  logos/jazeera.png     6.0  False              True           NaN
# 2      logos/fox.png     2.0  False             False           NaN
# 3                NaN     3.0  False              True          0.34
# 4      logos/sbt.gif     3.0  False             False          0.31
#
#                                        filename original_extension  \
# 0  BVx0nR366sk-3b0933b1902d9a66730d447258c425ec               webm
# 1  6Y1uTg7wCV8-b068dba553b7529eb2c2c4727c47fed9               webm
# 2  VuW-M9TB7tM-73472a9187f950d4812582d25154f1d4                mp4
# 3  gMz2bJykKaY-31b60bdf2a061902a1c004eab2ced596               webm
# 4  6QWIAsPOlxM-907ba6ac2932e487c215c9b364d06e14               webm
#
#                             new_filename  \
# 0  16560611413745a1b33748cad5cdb726.webm
# 1  4fe31156621142de9be93e3c6a4a8bd9.webm
# 2   49f397b693eb41a9b7c8a95b0147c6a0.mp4
# 3  e366f4367c2148c3bb4e88a6bf3b0835.webm
# 4  7611fe4baab94392a82f5a8a28bdeba2.webm
#
#                                    original_basename
# 0  BVx0nR366sk-3b0933b1902d9a66730d447258c425ec.webm
# 1  6Y1uTg7wCV8-b068dba553b7529eb2c2c4727c47fed9.webm
# 2   VuW-M9TB7tM-73472a9187f950d4812582d25154f1d4.mp4
# 3  gMz2bJykKaY-31b60bdf2a061902a1c004eab2ced596.webm
# 4  6QWIAsPOlxM-907ba6ac2932e487c215c9b364d06e14.webm

# %%
# Match Augmented to their counterparts
a_o = dict(zip(augmentation_manifesto['new_filename'],augmentation_manifesto['original_basename']))
vendorquery_df['original_basename_q'] = vendorquery_df['filename'].apply(lambda x:matching(x,a_o))
vendorquery_df['original_basename_m'] = vendorquery_df['match_filename'].apply(lambda x:matching(x,a_o))

# %%
per_a = vendorquery_df['original_basename_q'].value_counts()
msk = per_a[per_a > 1].index.values

# %%
restricted = vendorquery_df.loc[vendorquery_df['original_basename_q'].isin(msk),:]
# restricted = restricted.loc[restricted.isUnique == False,:]
restricted.shape
# Out:
# (1585, 6)

# %%
sum(restricted['original_basename_m'] == restricted['original_basename_q']) / restricted.shape[0]
# Out:
# 0.9570977917981073

# %%
sum(vendorquery_df['original_basename_m'] == vendorquery_df['original_basename_q'])
# Out:
# 2387

# %% [markdown]
# ## Analysing Results from our model

# %%
from winnow.feature_extraction import SimilarityModel


sm = SimilarityModel()

video_signatures = sm.predict(VIDEO_LEVEL_SAVE_FOLDER)
# Save Signatires
video_signatures.shape
# Out:
# (3843, 4096)
# (3843, 500)

# %%
video_signatures = np.nan_to_num(video_signatures)

# %%
filenames = [x.split('_vgg')[0].split('/')[-1] for x in  sm.index]

# %%
in_q = vendorquery_df['filename'].apply(lambda x:x.split('.')[0])

# %%
video_space = video_signatures[np.isin(filenames,in_q)]
labels = np.array(filenames)[np.isin(filenames,in_q)]

# %%
from sklearn.cluster import DBSCAN

# %%
clusters = DBSCAN(metric='cosine',eps=0.1,min_samples=1).fit_predict(video_space)

# %%
model_results = pd.DataFrame({'filename':labels,'cluster':clusters})

# %%
filename_original = a_o = dict(zip(augmentation_manifesto['new_filename'].apply(lambda x:x.split('.')[0]),augmentation_manifesto['original_basename']))

# %%
model_results['original_basename_q'] = model_results['filename'].apply(lambda x:matching(x,filename_original))
model_results['original_basename_q'] = model_results['original_basename_q'].apply(lambda x:x.split('.')[0])

# %%
model_results ['original_basename_m'] = 'NA'

# %%
for c in model_results.cluster.unique():
    
    msk = model_results.cluster == c
    prevailing = model_results.loc[msk,:].original_basename_q.value_counts().index.values[0]
    model_results.loc[msk,'original_basename_m'] = prevailing

# %%
sum(model_results['original_basename_m'] == model_results['original_basename_q'])
# Out:
# 2486

# %%
model_results['filename'].nunique()
# Out:
# 2500

# %%
model_results['isUnique'] = model_results['filename'] == model_results['original_basename_q']

# %%
model_results.isUnique.value_counts()
# Out:
# False    1551
# True      949
# Name: isUnique, dtype: int64

# %%
per_a = model_results['original_basename_q'].value_counts()
msk = per_a[per_a > 1].index.values
restricted = model_results.loc[restricted['original_basename_q'].isin(msk),:]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-56-275735a74835> in <module>
#       1 per_a = model_results['original_basename_q'].value_counts()
#       2 msk = per_a[per_a > 1].index.values
# ----> 3 restricted = model_results.loc[restricted['original_basename_q'].isin(msk),:]
#
# ~/.conda/envs/winnow/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~/.conda/envs/winnow/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# ~/.conda/envs/winnow/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1866             return self._get_slice_axis(key, axis=axis)
#    1867         elif com.is_bool_indexer(key):
# -> 1868             return self._getbool_axis(key, axis=axis)
#    1869         elif is_list_like_indexer(key):
#    1870
#
# ~/.conda/envs/winnow/lib/python3.6/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#    1491             axis = self.axis or 0
#    1492         labels = self.obj._get_axis(axis)
# -> 1493         key = check_bool_indexer(labels, key)
#    1494         inds, = key.nonzero()
#    1495         try:
#
# ~/.conda/envs/winnow/lib/python3.6/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    2354         mask = isna(result._values)
#    2355         if mask.any():
# -> 2356             raise IndexingError('Unalignable boolean Series provided as '
#    2357                                 'indexer (index of the boolean Series and of '
#    2358                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %%
msk
# Out:
# array(['7LYTx0IJtPY-983ff03d543f14a7fdf9f8e84e55f6b6',
#        'cW51HiyRXTk-102421b7f08102d49fa0d2ba8e792151',
#        '_IeeP6GgqAA-6d13b4ca9335abe139f9041d41ee24a3',
#        'vjSxK0g8E_w-3dbf4e5565cb6c549ce8707105cfecc3',
#        'xAIq2HtX_lk-7ddb270bece191e9e4dcab56fa46391e',
#        'epjbvDTIdF0-0eca92847d6dbf683f9afea77a544124',
#        'fOqdfZdmNEQ-4060ff05b68d5c33f74d426cb619c905',
#        'E6B3Hwsd5mM-f743130db139c5722a3a610dccf88b7d',
#        '8Rvu-jlsaOU-5b988b26edd0096ea42d3b804621d297',
#        'D3FpFnEvBTk-fe5d058c03547270eb52a229497b5256',
#        'AA82DdkVh5s-db5b2e3d870f1005da5e88c3e6b256f4',
#        '94g4ysN4qVs-657067b21447935a88b4da5a1a74eeac',
#        'FHF8jy9U694-416457c565713a90334d032a75d3ff93',
#        'jr6oGoqDEfI-8842ae65a03a5bdb8c23e78509adb4b1',
#        'fJa7D3Uzaas-7f59def97c7a906c066e5dec84bed753',
#        'VaO-OpFPg2A-0eee60c766905dd04230864eee939e21',
#        'LFnMl6Lj3co-11cf15e9ee5ae44575f2743de9812ee5',
#        'N1_SdQE1XME-09e54af56f7e9e22f4653052ebbb8054',
#        '6omIWrDq5dk-ce223270fa80bd30716227aa98e1ce26',
#        'rCZSuzJs4zc-c859578ffb45b422c0d737a005066f9f',
#        'uqPhRKah6EA-4d154dee35f9c714fa7653d76807de7a',
#        '5DMCF2sKJpU-859bbc2976278ae50e91639fbc4bad77',
#        'flsevUvm098-ba74e90711c9692f2a6a1157a6eaf146',
#        'IgyjoEgMuPA-784bc730ced19fb7d4b54284b6a6d747',
#        'JoxsB8x2mSc-f72ea72ee9bf3e8787d9a6498f8ef180',
#        'Y3n2AN8V6zY-90b83e926a61c6494cfdda9efb9809a5',
#        'kabNdo05sNw-0898375837dac959ab9c943a53b1f41e',
#        '0skcZddaa3Q-389610305899163cf6ddad122a54954e',
#        'FPeKK6AU6BM-0332ad7ffcf384368c777ae72c9c9e3f',
#        'Au6wyThNMGk-e4e7961b8eb424ab6cb4bedb7914abc9',
#        '38NgfwT8QdM-7833ee88770404616f1b76c17a11d2fb',
#        'lnZNiivm2zU-e1caaa59e5479f037914e52e0893cc6e',
#        'N95pg7IBN_E-7ca94b2b81faf965a184cc31082f5480',
#        'Mwi_5yFWlac-93b41f309974d7328d626db2dda4780e',
#        'dxZ4p7oRNpQ-9a9db9fca309340e31660b2b9c0c01f1',
#        'lbuGNC636tM-be97bb67b748580d77cb28588fbd8eff',
#        'zrlAGAb3OMY-bdcf43eb8ccddc3a67d2fb9c68d017ef',
#        'AgMNzWiOERs-31d7ad44766e44a5a4335e91298a2f01',
#        'TUgKmZ0uDBg-0b47c336d06279b013d9e675c2c6f77b',
#        'RO3B6_yL1gk-1eadec850c689b91737eddffba3d177a',
#        'tUdeqJZAqHo-c744327606fca36080ec3a934786da73',
#        'v_0zOruaXE4-4ef1ef7754a7e193e9a878c266a63556',
#        '4hUEzMxmCYs-062ed9380b05490ac97d6c23e0718e92',
#        'MIbehnQKDm8-34085787d9cbd858c668fd00e41bec69',
#        '9H_zNXMgTNE-49e34b8bb457bd873cf7dda0679df43c',
#        'rkaIhKVge08-2aea3752ef7cf58a71f7395397820bf1',
#        '3w5UH3iEBPs-1e698e236a4a82048c6232ab2828aa14',
#        'xAxnFeHpaXg-70fa2c2e464509fcbfb6b7437fc8873f',
#        '839npxFIFuw-eb2b470bd1ec2e96b4107fca1ac35971',
#        'gHp4ZSiX0gw-857b20dd1be02eeb0493fa2280904323',
#        'rq2S0dmXIFs-4cb4b3b985e02407a2d5eade69a8916a',
#        'Bx6y9YXPslg-2cbb67b012d75f99f7922496574bf02d',
#        '2xbKw8RNFec-6748687a448a8dfaaf6c935ef76ca000',
#        'Oa9o9qA7wcU-9acc3fc3527e060b643ce5b9e3e7eb63',
#        '69Ri7ItDmS4-5717b7b1f2d8f77c3a22532f2b1ce160',
#        'xZ-J-7JYA-k-0450ba787f460134f321dc0761a8ede7',
#        'W3UHKYaFdhg-7eb90000efc9da69d64b248cefadb023',
#        '0hhXGe3IMwM-283db3f185436f9715f21a8f383810f3',
#        '7hJTQNvFZq4-d825d5c07c00371f4d89d4df82aed1e5',
#        'pBW5mcO76kY-61a4d9d440831b46f9f2444f076a9be8',
#        'GWVHCj7C1Wo-8cc98d21fbdb449dead84bbc9855e3a6',
#        'UyhXoWjdmSk-e8c140e5322b4f3002b824a01199f7de',
#        'puME6wQyP98-f9659f8e6dcac0a1a45e7ea1741f28b8',
#        'hyVkqP13CIQ-51cae72eb6402ff451941044a23869b3',
#        'rGlgUU3E14Y-6d71ac0b941d2b74a2b52df03aaadd2f',
#        'u3VDtLG8E_Y-851998683165ea933867e69048bcd6b6',
#        'BBnf2pl_tf8-302b0f8a2a7fa4c661e6e96e85ac19d6',
#        'vHkJVH3goTI-87a6e2c8b6afdad64ca964290ba7a4c8',
#        'SRRMHY-g76E-811333b07f76521285883dc351d08eb6',
#        'tN2HCzebd8A-dfbde38f507c1aaf9234c238820f38b2',
#        'G_Q9IKbtYOk-7bc3b115458d1ba1798cd7e512a8d6aa',
#        'xD9ucZlmGg8-809c988d227a4d021486edb24bde58c7',
#        '8TtYaWTCLlg-fe860330381870662e320824449fe3c9',
#        'KpciFQt35ow-8dd996e4a8eed2340bb2110f5d37c48f',
#        'goQ997A-2Rg-3868cc0461d95b09288d921b22610192',
#        'b9ErO_x9nXg-67426bb8addcc272591cf476445e97d2',
#        'EJR-g-4eGEc-023ec07ea29583059af0bd5964976df6',
#        'qXPDuNNAdlk-0ac7016edec3a32c8151eda28872d318',
#        '7VLNL2dpc8Y-b6505348715554f6cc04725da3f0d756',
#        'dJcwxCZSSJk-ddb227986062a76d94f04a1ff45f39bd',
#        '4HcDSpWFmg0-79380a36b7587add31e998fb5180be2f',
#        'AxDxVNDEU3c-4afdd33901943e0e27f9f654cb96bd34',
#        'w7_aYG8OG_o-05a836be32d9421280288067bb5a6bdd',
#        'rYXGYt9nKXE-9e0b052a724e704a88ddbde41070af3a',
#        'r25t7t9EMUY-72a8c06b971cc31e84339927e9a1c54d',
#        'JdUdGSHbfl8-5f990d9a138f62056e554fd15ae55138',
#        'EWBFATBVjYQ-46953620e55d3305abd30448dd2fc40e',
#        'M8bruehznD4-80fdc424555c1756f1b0e30c5bdd94ff',
#        'i0XffHb8kz8-a014ab8d9266fd831a77de905f6b9342',
#        'RuVViSGgPxI-4fe210d5d2070424bef985ce616e369c',
#        '3oYWhauQ4fY-a7bc5c0789df4f5bfbccf443d0ae936e',
#        'pmooM-xMCvM-d42877881a6eb33524b3279fa61bd5b9',
#        'H67d9dw0n-w-c52b43a554c7177c036309f9fa023f75',
#        'QtGnq1hTpSY-07b3e3a984a3cf7a8b4bc9c95584e274',
#        '93hsYr5mg5k-112e46a5f90427b50cb831663254083d',
#        'aGHwuX_afPs-8f923c6a575a3e8760eed7e4bbccaa95',
#        'S21kK7M8wz0-4a910daa08b9eac3aeef6019e2eb22f5',
#        'ohngCDAw4QI-50c283e39de3da07592e9ccd3a3e4fa1',
#        'HqNujQunFnU-5325de3ee508b2af33627705d32d816c',
#        'FPHwWDLpSNo-a5fd7bfdd61c4734fabe5b6cd1beb0db',
#        '0VJftxGtl-g-d565313dbb9abf90d098546efd0a3525',
#        'nj2rodAwxMU-6b7ff9e467e230892e4cf4cd8abbbedc',
#        'wfublzggEpU-e4889b75a8aa6dc6af0f60b352fdcd04',
#        '3gGiQ62u1K4-ed5db8af35f738150baf065668a56411',
#        'AXSkJqJqtu4-94b35398f2be0742586841997340e1d7',
#        'BAy4ztYUaX8-c4192cba58779ef2291b623e2c866a5d',
#        '3TiDAKydHic-a342d8bfb943e59152638c3ff9a1a26e',
#        'kBDNvVq8ut4-93a3c69f5246717d15d91a47238c32e9',
#        '9oziuihslYw-4e40b91603b42b60ce2cf5cf1853ded1',
#        'jO6ZXTWX-PA-489942194feef43d0c998f13255ecc32',
#        'GyaFEZujpbY-e2e5d448e968fd988bf891592ef744af',
#        'GfoKkUIzbjA-0fc69ee07cdaafa836651abda9576760',
#        '0JQpBUG7kP8-dfc38248b5967e3136b676cb70de01ba',
#        'qRP6ruit2mA-4ed8299d892230b0c96dc5ecce67f7ae',
#        '82KKCxXUAW8-bb274a3c804764d45d8daa89f170949e',
#        '_5g95MUIieM-7673d38ccc6e268bf6d79e61f388d37b',
#        'Rp9bvNSp0Wc-3cbb32a560246b5513d3388f79d9cef3',
#        'JPvcAKQf8hI-74214a6c9573145bdd6734f36f5d4dfd',
#        'orHJUtltQy0-dced690a7dd18894605e30bae842c208',
#        'xJbEsCKYsEk-d798885afce72ee6d5a7e1b55a9a163f',
#        '3BP5PFiHyb0-21f13125ad10f2ce5e72bd2a20ca5b32',
#        'uexCWmLsCo0-b90624e7caf66928a0987e872cdb81a6',
#        'q3OqXMoPXh8-ae5381b81ab04e6aa8f45bad966dbaaa',
#        '0WYW0PIwvZI-578d2311e2400479811356035066a45c',
#        'Y0sBlKQ2VE4-17b6e3ff8e9372f6151634ee746d145d',
#        'DfaPkeyYcMU-d920474fecf21e0ba16ab1505ef5c635',
#        'nlYDp0XIFyk-bdc9a88f2f450aa4c792ea7ec0629233',
#        '9_2XFkMYLXY-4ffb85a368877ab5db739826d2bc6f98',
#        'HPeZtufLKac-ff35b4e9880807d6ce5e429eb18eb5d4',
#        '22Ql6gOuUB4-8604ec2841ac1a05f15fa65719cf3075',
#        '4HvbbzmWtZQ-2af483979e16ba32e3004a34d679e148',
#        '0w2lCxNansE-131699d0aada312e68da0d54d8210602',
#        's3m3kPRyVGM-510f58a179aa2178f401506777149681',
#        'S6pQ0KuAWlU-41478f43f994aadcfe57411afe178344',
#        'OK-mPTKNvDo-e259f1866f41c2c3013191f7a5a3204f',
#        'H6q_C70KwpM-67595e0d7be55383e30bf0f4418dc9b3',
#        'Xaqh1tm4FrY-76d4db7ceac7aa9acee2611a5e5ffa15',
#        'g0HFuE0_q2c-4f3ca3a966ce235d6b629d6d7b7b7564',
#        'ESaxuHLCqiw-0f22808a1b3ac95b3b7f9c6600ab2ced',
#        'NAtjXRWt8RA-30d73b0003cc42310b690082363cdae5',
#        'Dy_7KUTKEWE-b7d7eb4ae030eb22f16bbb95a3f9bf12',
#        'i3RUO5BxdAQ-a801f98ef3b6041f8c30f4ac684d9159',
#        'S3RfAROw2gg-9d948ffa9a2a0db206844b54269e82a0',
#        'BCn8TM5HUrE-d70324addccf921b422eede23d770818',
#        'iNvmwxkoJUU-01adc1bd901b62c1c7072cd37fb5fc59',
#        '5HYaaDqK3Ow-28c51dc33f9199c8957d06ca327482dd',
#        'P--VSarTxP8-8d2ae753ef1725a71e11d8d0c9bf2b65',
#        'c-0Hn5Xi0nw-6dc0655617b59aa956e77f5946e30862',
#        'DVoAtKHiZ0w-5866eb91997806edf7010b94a42a5f62',
#        '4ZQ_UHDeWTA-620aebf76618bcc9e1aba51701127df1',
#        'OS43ow6pbNQ-f225b5e2b3ddc2add5962ffd350e9d8f',
#        'xk8Xoa60sFE-2c3ff073729dbc9e0caced24817518f8',
#        'YOfWo6I3ax0-74d95aa820d3ebc003ef8a0225e609cd',
#        'DIdgEqiKfDs-20f40191bf0bb9e9e3a8930d6f9ec7ca',
#        'CuQj8oNR-1I-d2d165bd782563419d35fffaed8ae0d9',
#        'Jn-K0JVVnHY-b0cddbfec1a38cc8de863ea986e1dcbe',
#        'CsNJYKv4SZA-48419cdaae3f1f14eb715b4f79b97fef',
#        'iZAGMHLJ2U8-0a2d3652c2e8132baf9593de3cfae8b1',
#        'uFybM4QdNXE-24b42959a805fdab20e1e2e2bd48bd0c',
#        'Xaj3LhIY07s-a13fcb07fd13e3f63bde9bda6dd55f13',
#        'rWnAp4JX-Ms-3481ead696ab5fde7257d96937525f78',
#        'g-IzqjYl3fA-42b4f273379ffd5372e165924933fb46',
#        'h6UramvA7RA-4b3f028c49ddcc98c1b2a7fda460cdfc',
#        'wGEoKmgcDMg-e7567ba3d9f0d743de66d8759e35e7e2',
#        'Dj2a090fn4I-ee7ae23bca316c2d6988231d849b0b37',
#        'F6MyTJUCPZw-7e71ae6b0ed4c1946f550ce5bee01f5d',
#        'l3HAflwGwj8-35063040003d449041c19a1a3fd71138',
#        '5sl98RjqVgc-19dd304495cab317f61188b5ca4b4eb1',
#        'R-_1Aip_GNE-4142747702602b06e9ffc7e15b640ac9',
#        'T5n5PiMF93s-42c5b2f4bca04483e5fe23cdf38c3b7c',
#        '6NAQ9c4EVTs-6b8a5843f4efb1fd7d25a58c1bde3296',
#        '34Sozqs9YD8-c6894173310fbbbff578095cd9bdf9c7',
#        'ftXeM1Y0Qfo-d6044274d6c7c0b604f9ac273447a6ce',
#        'shhcEu9baFY-a952804fb8e99684890d903fba9c8cd5',
#        'QA3KRnwpPRc-918d81e74e44013f26b1d3df75d8bcc5',
#        'lQRHXz_UD8E-32f8879f93b258d381051670cfd4a7cb',
#        'SoQB35MA4cQ-9125c7f196154e8f92caaed86fde4ccf',
#        'gN472k0oHFg-5cf5e169175d1bb4947ff0fd60d6f370',
#        'eT2W3VRsF-I-83887937a52a18fcc60be45bf7096747',
#        'pgERmiWxR3s-a7c2e57b2fc3aa137ec3a7ba33a6a18c',
#        '1X1oZUAW5ds-a017ae11dcedfd0eb915278a1783e375',
#        'jaRuDP6txBQ-b686ba80eae215094f4dd5849c07f265',
#        '00emEaHcZUc-2035f2f4f51b5f08263ce9a0e3ba88cc',
#        '_bja8VCDY_w-129f9c4b34cfe6227d4311231e08ee3f',
#        'cVrs5Qsnv1U-764e066c86851edb8bc63660ab1b5647',
#        'xW0WYnr_zD4-cb470ee7cb73c51174f8afd7805a106a',
#        'HGHgnvILnZI-922d330e54db7110ffe5016b7301d915',
#        '4Qpcf3Kx6xI-ac5647fba065f6679c92ee15cc428a8b',
#        'LN5dkJjCHbI-6d0b8ef99bb7e909c81166849150fb35',
#        'Ku3arTrM0jg-8dc21d6fbeaddaa7a6cd6e5a86c90b4e',
#        'DxhikT_riJk-3b3e85d1a3979eb5e55ab6a02fa4a46d',
#        'yp2flos0Nrw-32ecbc1606993592b99a1ed2b00d40dd',
#        'Q3QNcNmOTrM-4ed3a9586916368acf044ac7e7e67bfd',
#        'q80AZNKj2lQ-168122fb3f99bd4cc36816b1d06837fa'], dtype=object)
